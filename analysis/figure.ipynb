# %%
import pandas as pd
from astropy.table import Table, QTable
import astropy.units as u
from astropy.time import Time
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('cfht_eqw_results.csv')
data.rename(columns={'Time(Y,M,D,H,M,S)':'time'}, inplace=True)
data['MJD'] = np.zeros(len(data))
mjds = []
files = []
for obj in data.itertuples():
    filename = obj[1]
    year = obj[3].split()[0]
    y = int(year.strip('(,'))
    month = obj[3].split()[1]
    m = int(month.strip(','))
    day = obj[3].split()[2]
    d = int(day.strip(','))
    hour = obj[3].split()[3]
    h = int(hour.strip(','))
    minute = obj[3].split()[4]
    min = int(minute.strip(','))
    second = obj[3].split()[5]
    s = int(second.strip(',)'))
   
    mjd = Time(datetime(y,m,d,h,min,s), scale='utc').to_value('mjd')

    mjds.append(mjd)
    files.append(filename)

data['MJD'] = mjds
#data

# %%
type(data.iloc[1][3])
# Out:
# /var/folders/s0/h_46lpt56ll2ptpy3684xkym0000gn/T/ipykernel_23205/2971355092.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   type(data.iloc[1][3])
# numpy.float64

# %%
data_soar = {"data_set":["soar_m5"], "EQW_Value":[float(.93472176)], "time":["0"], "MJD":[Time(datetime(2025, 9, 16, 5, 43, 40), scale='utc').to_value('mjd')]}
df = pd.DataFrame(data_soar)
data_new = pd.concat([data, df], ignore_index=True)

# %%
data_new
# Out:
#          data_set  EQW_Value                       time           MJD
# 0   1849608i.fits   0.403780  (2015, 11, 29, 6, 44, 41)  57355.281030
# 1   1849608p.fits   0.348976  (2015, 11, 29, 6, 54, 10)  57355.287616
# 2   1849609i.fits   0.403691  (2015, 11, 29, 6, 44, 42)  57355.281042
# 3   1849610i.fits   0.403255   (2015, 11, 29, 6, 45, 9)  57355.281354
# 4   1849611i.fits   0.404661  (2015, 11, 29, 6, 44, 46)  57355.281088
# 5   2558520p.fits   0.338902    (2020, 12, 5, 7, 2, 18)  59188.293264
# 6   2558524p.fits   0.295671     (2020, 12, 5, 7, 4, 7)  59188.294525
# 7   2558528p.fits   0.434964    (2020, 12, 5, 7, 5, 48)  59188.295694
# 8   2558532p.fits   0.418538    (2020, 12, 5, 7, 7, 32)  59188.296898
# 9   2558536p.fits   0.315501    (2020, 12, 5, 7, 9, 18)  59188.298125
# 10  2558540p.fits   0.487089   (2020, 12, 5, 7, 10, 53)  59188.299225
# 11  2558544p.fits   0.304122   (2020, 12, 5, 7, 12, 36)  59188.300417
# 12  2558548p.fits   2.271039   (2020, 12, 5, 7, 14, 16)  59188.301574
# 13   812176i.fits   0.414850    (2012, 5, 9, 14, 37, 8)  56056.609120
# 14   812177i.fits   0.412569    (2012, 5, 9, 14, 37, 9)  56056.609132
# 15   812178i.fits   0.415271    (2012, 5, 9, 14, 43, 0)  56056.613194
# 16   812179i.fits   0.416449    (2012, 5, 9, 14, 43, 4)  56056.613241
# 17   813127p.fits   0.329443   (2012, 4, 20, 9, 56, 14)  56037.414051
# 18   813131p.fits   0.389142   (2012, 4, 20, 9, 42, 17)  56037.404363
# 19   813135p.fits   0.386022  (2012, 4, 20, 10, 31, 32)  56037.438565
# 20   813139p.fits   0.394107    (2012, 4, 20, 10, 0, 0)  56037.416667
# 21   813143p.fits   0.418605  (2012, 4, 20, 11, 22, 10)  56037.473727
# 22   813147p.fits   0.351645  (2012, 4, 20, 10, 34, 58)  56037.440949
# 23   813338i.fits   0.406997    (2012, 4, 20, 8, 17, 3)  56037.345174
# 24   813339i.fits   0.401346   (2012, 4, 20, 8, 16, 56)  56037.345093
# 25   813341i.fits   0.407976    (2012, 4, 20, 8, 19, 3)  56037.346563
# 26   813342i.fits   0.407355    (2012, 4, 20, 8, 19, 2)  56037.346551
# 27   813343i.fits   0.408636    (2012, 4, 20, 8, 19, 1)  56037.346539
# 28   813462i.fits   0.411019   (2012, 4, 20, 8, 10, 51)  56037.340868
# 29   813463i.fits   0.404369   (2012, 4, 20, 8, 10, 50)  56037.340856
# 30   813464i.fits   0.410572   (2012, 4, 20, 8, 22, 31)  56037.348970
# 31   813466i.fits   0.411301   (2012, 4, 20, 8, 22, 20)  56037.348843
# 32   813467i.fits   0.410771   (2012, 4, 20, 8, 22, 21)  56037.348854
# 33   813468i.fits   0.407410   (2012, 4, 20, 8, 22, 19)  56037.348831
# 34   852267i.fits   0.406783  (2012, 3, 14, 13, 20, 16)  56000.555741
# 35   852268i.fits   0.406515   (2012, 3, 14, 13, 32, 8)  56000.563981
# 36   852283i.fits   0.407271  (2012, 3, 14, 13, 35, 41)  56000.566447
# 37   852284i.fits   0.404101  (2012, 3, 14, 13, 35, 37)  56000.566400
# 38   852459i.fits   0.407305   (2012, 3, 14, 17, 5, 53)  56000.712419
# 39   852460i.fits   0.406650   (2012, 3, 14, 17, 5, 53)  56000.712419
# 40   852461i.fits   0.406484   (2012, 3, 14, 17, 5, 53)  56000.712419
# 41   852582i.fits   0.408991  (2012, 3, 12, 13, 59, 41)  55998.583113
# 42   852583i.fits   0.408189  (2012, 3, 12, 14, 10, 40)  55998.590741
# 43   852584i.fits   0.405727   (2012, 3, 12, 14, 3, 17)  55998.585613
# 44   852585i.fits   0.407908   (2012, 3, 12, 14, 14, 8)  55998.593148
# 45   852694i.fits   0.403553   (2012, 3, 16, 9, 12, 36)  56002.383750
# 46   852695i.fits   0.401521    (2012, 3, 16, 9, 6, 27)  56002.379479
# 47   852696i.fits   0.403277    (2012, 3, 16, 9, 6, 22)  56002.379421
# 48   852697i.fits   0.403367    (2012, 3, 16, 9, 6, 11)  56002.379294
# 49        soar_m5   0.934722                          0  60934.238657

# %%
times= np.array(data['MJD'])
widths = np.array(data['EQW_Value'])

times2= np.array(df['MJD'])
widths2 = np.array(df['EQW_Value'])

fig, ax = plt.subplots(figsize=(12, 6))#.figure(figsize=(12, 6))
ax.scatter(times, widths, s=25, label='CFHT/ESPaDOnS')
ax.scatter(times2, widths2, s=25, label='SOAR/GOODMAN')
ax.legend()
ax.set_xlabel('Time (BJD)')
ax.set_ylabel('H$\u03B1$ Equivalent Width')
#ax.set_ylim(0,1.0)
ax.set_title('Full Observational Timescale')
# Out:
# Text(0.5, 1.0, 'Full Observational Timescale')
